# %%
a = [2, 3, 4, 5, 6]
print("a =", a)

rev_a = []

for _ in range(len(a)):
    rev_a.append(a.pop())

print("rev_a =", rev_a)
# Out:
# a = [2, 3, 4, 5, 6]
# rev_a = [6, 5, 4, 3, 2]

# %%
my_tuple = (1, 2, 5, 4, 3, 2, 1, 4, 7, 8, 9, 9, 3, 7, 3)
print("주어진 튜플은:", my_tuple)

count_dict = {}

for element in my_tuple:
    if element in count_dict:
        count_dict[element] += 1
    else:
        count_dict[element] = 1

max_count = max(count_dict.values())

most_frequent = []
for key, value in count_dict.items():
    if value == max_count:
        most_frequent.append(key)
max_value = max(most_frequent)

print("가장 많이 나타나는 원소는:", max_value)
# Out:
# 주어진 튜플은: (1, 2, 5, 4, 3, 2, 1, 4, 7, 8, 9, 9, 3, 7, 3)
# 가장 많이 나타나는 원소는: 3

# %%
menu = {
    "Americano": 3000,
    "Ice Americano": 3500,
    "Cappuccino": 4000,
    "Cafe Latte": 4500,
    "Espresso": 3600
}

for key in menu:
    print("{:16s}가격 : {:,}원".format(key, menu[key]))
# Out:
# Americano       가격 : 3,000원
# Ice Americano   가격 : 3,500원
# Cappuccino      가격 : 4,000원
# Cafe Latte      가격 : 4,500원
# Espresso        가격 : 3,600원

# %%
menu = {
    "Americano": 3000,
    "Ice Americano": 3500,
    "Cappuccino": 4000,
    "Cafe Latte": 4500,
    "Espresso": 3600
}

for key in menu:
    print("{:16s}가격 : {:,}원".format(key, menu[key]))

check = 'y'
while (check=='y'):
    choice = input('위의 메뉴중 하나를 선택하세요: ')
    if choice in menu.keys():
        print('{}는 {:,}원 입니다. 결제를 부탁합니다.'.format(choice, menu[choice]))
    else:
        print('미안합니다. {}는 메뉴에 없습니다'.format(choice))
    print('계속 주문하시겠습니까?')
    print('y/n')
    check = input()
# Out:
# Americano       가격 : 3,000원
# Ice Americano   가격 : 3,500원
# Cappuccino      가격 : 4,000원
# Cafe Latte      가격 : 4,500원
# Espresso        가격 : 3,600원
# 위의 메뉴중 하나를 선택하세요: Espresso
# Espresso는 3,600원 입니다. 결제를 부탁합니다.
# 계속 주문하시겠습니까?
# y/n
# y
# 위의 메뉴중 하나를 선택하세요: latte
# 미안합니다. latte는 메뉴에 없습니다
# 계속 주문하시겠습니까?
# y/n
# n
