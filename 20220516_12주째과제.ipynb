# %%
import pandas as pd
raw_data  = pd.read_csv('./survey_results_public.csv')
raw_data.info()

target_data = raw_data[['Age', 'Country', 'LanguageHaveWorkedWith', 'LearnCode']]
target_data.head()

size_by_LearnCode = target_data.groupby('LearnCode').size()
size_by_LearnCode

methods = target_data['LearnCode']
methods

methods = methods.str.split(';')
methods

exploded_methods = methods.explode()
exploded_methods

size_by_methods = exploded_methods.groupby(exploded_methods).size()
size_by_methods

size_by_methods.nlargest(10).plot.pie(figsize=(5,5), autopct='%1.0f%%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84212 entries, 0 to 84211
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           84212 non-null  int64
#  1   Q120                                 84212 non-null  object
#  2   MainBranch                           84212 non-null  object
#  3   Age                                  84212 non-null  object
#  4   Employment                           83024 non-null  object
#  5   RemoteWork                           70268 non-null  object
#  6   CodingActivities                     70227 non-null  object
#  7   EdLevel                              83095 non-null  object
#  8   LearnCode                            82802 non-null  object
#  9   LearnCodeOnline                      66066 non-null  object
#  10  LearnCodeCoursesCert                 34909 non-null  object
#  11  YearsCode                            82592 non-null  object
#  12  YearsCodePro                         63158 non-null  object
#  13  DevType                              73093 non-null  object
#  14  OrgSize                              62094 non-null  object
#  15  PurchaseInfluence                    62018 non-null  object
#  16  TechList                             57426 non-null  object
#  17  BuyNewTool                           78453 non-null  object
#  18  Country                              83095 non-null  object
#  19  Currency                             62364 non-null  object
#  20  CompTotal                            46094 non-null  float64
#  21  LanguageHaveWorkedWith               82317 non-null  object
#  22  LanguageWantToWorkWith               76231 non-null  object
#  23  DatabaseHaveWorkedWith               69450 non-null  object
#  24  DatabaseWantToWorkWith               57615 non-null  object
#  25  PlatformHaveWorkedWith               60265 non-null  object
#  26  PlatformWantToWorkWith               48585 non-null  object
#  27  WebframeHaveWorkedWith               63212 non-null  object
#  28  WebframeWantToWorkWith               53533 non-null  object
#  29  MiscTechHaveWorkedWith               53999 non-null  object
#  30  MiscTechWantToWorkWith               44387 non-null  object
#  31  ToolsTechHaveWorkedWith              73670 non-null  object
#  32  ToolsTechWantToWorkWith              64600 non-null  object
#  33  NEWCollabToolsHaveWorkedWith         81128 non-null  object
#  34  NEWCollabToolsWantToWorkWith         72396 non-null  object
#  35  OpSysPersonal use                    81754 non-null  object
#  36  OpSysProfessional use                74337 non-null  object
#  37  OfficeStackAsyncHaveWorkedWith       65584 non-null  object
#  38  OfficeStackAsyncWantToWorkWith       50996 non-null  object
#  39  OfficeStackSyncHaveWorkedWith        78868 non-null  object
#  40  OfficeStackSyncWantToWorkWith        65937 non-null  object
#  41  AISearchHaveWorkedWith               52826 non-null  object
#  42  AISearchWantToWorkWith               43233 non-null  object
#  43  AIDevHaveWorkedWith                  24176 non-null  object
#  44  AIDevWantToWorkWith                  18240 non-null  object
#  45  NEWSOSites                           83094 non-null  object
#  46  SOVisitFreq                          82330 non-null  object
#  47  SOAccount                            82986 non-null  object
#  48  SOPartFreq                           63073 non-null  object
#  49  SOComm                               82832 non-null  object
#  50  SOAI                                 45209 non-null  object
#  51  AISelect                             83094 non-null  object
#  52  AISent                               57751 non-null  object
#  53  AIAcc                                36033 non-null  object
#  54  AIBen                                57647 non-null  object
#  55  AIToolInterested in Using            30620 non-null  object
#  56  AIToolCurrently Using                33732 non-null  object
#  57  AIToolNot interested in Using        19719 non-null  object
#  58  AINextVery different                 11666 non-null  object
#  59  AINextNeither different nor similar  6170 non-null   object
#  60  AINextSomewhat similar               5841 non-null   object
#  61  AINextVery similar                   2468 non-null   object
#  62  AINextSomewhat different             21691 non-null  object
#  63  TBranch                              62760 non-null  object
#  64  ICorPM                               41749 non-null  object
#  65  WorkExp                              41663 non-null  float64
#  66  Knowledge_1                          40665 non-null  object
#  67  Knowledge_2                          39837 non-null  object
#  68  Knowledge_3                          39962 non-null  object
#  69  Knowledge_4                          39853 non-null  object
#  70  Knowledge_5                          39697 non-null  object
#  71  Knowledge_6                          39694 non-null  object
#  72  Knowledge_7                          39645 non-null  object
#  73  Knowledge_8                          39586 non-null  object
#  74  Frequency_1                          40082 non-null  object
#  75  Frequency_2                          40088 non-null  object
#  76  Frequency_3                          39276 non-null  object
#  77  TimeSearching                        40899 non-null  object
#  78  TimeAnswering                        40764 non-null  object
#  79  ProfessionalTech                     39956 non-null  object
#  80  Industry                             35170 non-null  object
#  81  SurveyLength                         81685 non-null  object
#  82  SurveyEase                           81752 non-null  object
#  83  ConvertedCompYearly                  45902 non-null  float64
# dtypes: float64(3), int64(1), object(80)
# memory usage: 54.0+ MB
# <Axes: ylabel='LearnCode'>
